# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 619

# %%
#Set units for search
units = "metric"

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | juybar
# Processing Record 3 of Set 1 | batagay
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | burica
# City not found. Skipping...
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | forbes
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | iquitos
# Processing Record 14 of Set 1 | vila franca do campo
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | robertson
# Processing Record 17 of Set 1 | hansot
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | vila velha
# Processing Record 20 of Set 1 | humaita
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | college
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | nanakuli
# Processing Record 25 of Set 1 | atar
# Processing Record 26 of Set 1 | anupgarh
# Processing Record 27 of Set 1 | bangassou
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | kirakira
# Processing Record 32 of Set 1 | ahipara
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | tamiahua
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | jalu
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | corinto
# Processing Record 43 of Set 1 | sao joao da barra
# Processing Record 44 of Set 1 | santa lucia
# Processing Record 45 of Set 1 | brae
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | pangnirtung
# Processing Record 48 of Set 1 | zhigansk
# Processing Record 49 of Set 1 | wewak
# Processing Record 50 of Set 1 | vaini
# Processing Record 0 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | elko
# Processing Record 2 of Set 2 | kosh-agach
# Processing Record 3 of Set 2 | amboasary
# Processing Record 4 of Set 2 | sorong
# Processing Record 5 of Set 2 | constitucion
# Processing Record 6 of Set 2 | chico
# Processing Record 7 of Set 2 | lowestoft
# Processing Record 8 of Set 2 | fukue
# Processing Record 9 of Set 2 | saint-michel-des-saints
# Processing Record 10 of Set 2 | kralendijk
# Processing Record 11 of Set 2 | cabo san lucas
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | saint anthony
# Processing Record 14 of Set 2 | port moresby
# Processing Record 15 of Set 2 | verkhnyaya inta
# Processing Record 16 of Set 2 | port hardy
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | portage
# Processing Record 20 of Set 2 | winslow
# Processing Record 21 of Set 2 | pisco
# Processing Record 22 of Set 2 | ulladulla
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | ayan
# Processing Record 27 of Set 2 | saint-pierre
# Processing Record 28 of Set 2 | bolonchen
# City not found. Skipping...
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | alofi
# Processing Record 31 of Set 2 | alice springs
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | nagua
# Processing Record 35 of Set 2 | reftinskiy
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | borba
# Processing Record 38 of Set 2 | cuenca
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | pita
# Processing Record 41 of Set 2 | namibe
# Processing Record 42 of Set 2 | sudogda
# Processing Record 43 of Set 2 | flinders
# Processing Record 44 of Set 2 | persianovskiy
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | billings
# Processing Record 49 of Set 2 | bluff
# Processing Record 0 of Set 3 | chapais
# Processing Record 1 of Set 3 | layou
# Processing Record 2 of Set 3 | okha
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | syracuse
# Processing Record 5 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 3 | emba
# Processing Record 8 of Set 3 | goderich
# Processing Record 9 of Set 3 | compostela
# Processing Record 10 of Set 3 | nemuro
# Processing Record 11 of Set 3 | awjilah
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 3 | kuytun
# Processing Record 15 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 3 | coihaique
# Processing Record 17 of Set 3 | bandarbeyla
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | san andres
# Processing Record 21 of Set 3 | cherskiy
# Processing Record 22 of Set 3 | makakilo city
# Processing Record 23 of Set 3 | chaihe
# Processing Record 24 of Set 3 | fonte boa
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | pangai
# Processing Record 28 of Set 3 | souillac
# Processing Record 29 of Set 3 | ilovlya
# Processing Record 30 of Set 3 | uray
# Processing Record 31 of Set 3 | yekaterinoslavka
# Processing Record 32 of Set 3 | ratnagiri
# Processing Record 33 of Set 3 | kindu
# Processing Record 34 of Set 3 | punto fijo
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | sao filipe
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | nome
# Processing Record 39 of Set 3 | asau
# Processing Record 40 of Set 3 | port blair
# Processing Record 41 of Set 3 | margate
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 3 | aklavik
# Processing Record 45 of Set 3 | mugur-aksy
# Processing Record 46 of Set 3 | sao felix do xingu
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | taganak
# Processing Record 49 of Set 3 | wamba
# Processing Record 0 of Set 4 | lebu
# Processing Record 1 of Set 4 | vostok
# Processing Record 2 of Set 4 | port alfred
# Processing Record 3 of Set 4 | rundu
# Processing Record 4 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | prince rupert
# Processing Record 7 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 4 | kavaratti
# Processing Record 9 of Set 4 | maldonado
# Processing Record 10 of Set 4 | katsuura
# Processing Record 11 of Set 4 | buchanan
# Processing Record 12 of Set 4 | sahuaripa
# Processing Record 13 of Set 4 | rochester
# Processing Record 14 of Set 4 | broken hill
# Processing Record 15 of Set 4 | nanortalik
# Processing Record 16 of Set 4 | east london
# Processing Record 17 of Set 4 | sola
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | bay roberts
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | carbondale
# Processing Record 22 of Set 4 | beyneu
# Processing Record 23 of Set 4 | trinidad
# Processing Record 24 of Set 4 | olafsvik
# Processing Record 25 of Set 4 | yerbogachen
# Processing Record 26 of Set 4 | barrow
# Processing Record 27 of Set 4 | port hawkesbury
# Processing Record 28 of Set 4 | kyren
# Processing Record 29 of Set 4 | bilibino
# Processing Record 30 of Set 4 | boundiali
# Processing Record 31 of Set 4 | luderitz
# Processing Record 32 of Set 4 | wuxue
# Processing Record 33 of Set 4 | torbay
# Processing Record 34 of Set 4 | khatanga
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | barmer
# Processing Record 38 of Set 4 | evinayong
# Processing Record 39 of Set 4 | ascension
# Processing Record 40 of Set 4 | oistins
# Processing Record 41 of Set 4 | sitka
# Processing Record 42 of Set 4 | sao lourenco do sul
# Processing Record 43 of Set 4 | hovd
# Processing Record 44 of Set 4 | kuroiso
# Processing Record 45 of Set 4 | abu samrah
# Processing Record 46 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 4 | khani
# Processing Record 48 of Set 4 | crisan
# Processing Record 49 of Set 4 | san cristobal
# Processing Record 0 of Set 5 | sapa
# Processing Record 1 of Set 5 | murray bridge
# Processing Record 2 of Set 5 | plainview
# Processing Record 3 of Set 5 | cauquenes
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | biak
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | falam
# Processing Record 8 of Set 5 | berlevag
# Processing Record 9 of Set 5 | jardim
# Processing Record 10 of Set 5 | nantucket
# Processing Record 11 of Set 5 | villamar
# Processing Record 12 of Set 5 | mendahara
# City not found. Skipping...
# Processing Record 13 of Set 5 | malur
# Processing Record 14 of Set 5 | vrsac
# Processing Record 15 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | grindavik
# Processing Record 18 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | steinbach
# Processing Record 21 of Set 5 | oranjemund
# Processing Record 22 of Set 5 | atyrau
# Processing Record 23 of Set 5 | la ronge
# Processing Record 24 of Set 5 | yokadouma
# Processing Record 25 of Set 5 | binga
# Processing Record 26 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 27 of Set 5 | terney
# Processing Record 28 of Set 5 | northam
# Processing Record 29 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 5 | narsaq
# Processing Record 31 of Set 5 | gao
# Processing Record 32 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 5 | lewiston
# Processing Record 34 of Set 5 | kostomuksha
# Processing Record 35 of Set 5 | ambunti
# Processing Record 36 of Set 5 | benoy
# Processing Record 37 of Set 5 | evanston
# Processing Record 38 of Set 5 | xining
# Processing Record 39 of Set 5 | fallon
# Processing Record 40 of Set 5 | emborion
# Processing Record 41 of Set 5 | delta del tigre
# Processing Record 42 of Set 5 | beloha
# Processing Record 43 of Set 5 | matara
# Processing Record 44 of Set 5 | oussouye
# Processing Record 45 of Set 5 | novokruchininskiy
# Processing Record 46 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 47 of Set 5 | lieksa
# Processing Record 48 of Set 5 | birobidzhan
# Processing Record 49 of Set 5 | marawi
# Processing Record 0 of Set 6 | tadine
# Processing Record 1 of Set 6 | shimoda
# Processing Record 2 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 6 | dunedin
# Processing Record 4 of Set 6 | bonthe
# Processing Record 5 of Set 6 | padang
# Processing Record 6 of Set 6 | annau
# Processing Record 7 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 6 | abnub
# Processing Record 9 of Set 6 | poum
# Processing Record 10 of Set 6 | nikolskoye
# Processing Record 11 of Set 6 | kings mountain
# Processing Record 12 of Set 6 | los llanos de aridane
# Processing Record 13 of Set 6 | werota
# Processing Record 14 of Set 6 | misratah
# Processing Record 15 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 6 | ridgecrest
# Processing Record 18 of Set 6 | chumikan
# Processing Record 19 of Set 6 | barahona
# Processing Record 20 of Set 6 | maniitsoq
# Processing Record 21 of Set 6 | whitley bay
# Processing Record 22 of Set 6 | tiksi
# Processing Record 23 of Set 6 | tual
# Processing Record 24 of Set 6 | beringovskiy
# Processing Record 25 of Set 6 | pilar
# Processing Record 26 of Set 6 | geraldton
# Processing Record 27 of Set 6 | carnarvon
# Processing Record 28 of Set 6 | chitungwiza
# Processing Record 29 of Set 6 | bontang
# Processing Record 30 of Set 6 | lucea
# Processing Record 31 of Set 6 | barsovo
# Processing Record 32 of Set 6 | dingle
# Processing Record 33 of Set 6 | khorixas
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 6 | pevek
# Processing Record 38 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 6 | aripuana
# Processing Record 41 of Set 6 | mersing
# Processing Record 42 of Set 6 | lagoa
# Processing Record 43 of Set 6 | shubarkuduk
# Processing Record 44 of Set 6 | ancud
# Processing Record 45 of Set 6 | viedma
# Processing Record 46 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 6 | coroneo
# Processing Record 48 of Set 6 | roald
# Processing Record 49 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 0 of Set 7 | navalmoral de la mata
# Processing Record 1 of Set 7 | saint-augustin
# Processing Record 2 of Set 7 | dauriya
# Processing Record 3 of Set 7 | beya
# Processing Record 4 of Set 7 | taonan
# Processing Record 5 of Set 7 | nouadhibou
# Processing Record 6 of Set 7 | isla mujeres
# Processing Record 7 of Set 7 | autazes
# Processing Record 8 of Set 7 | daru
# Processing Record 9 of Set 7 | omboue
# Processing Record 10 of Set 7 | half moon bay
# Processing Record 11 of Set 7 | chenghai
# Processing Record 12 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 7 | la primavera
# Processing Record 14 of Set 7 | kutum
# Processing Record 15 of Set 7 | gamba
# Processing Record 16 of Set 7 | gornopravdinsk
# Processing Record 17 of Set 7 | sioux lookout
# Processing Record 18 of Set 7 | koslan
# Processing Record 19 of Set 7 | manacor
# Processing Record 20 of Set 7 | hamilton
# Processing Record 21 of Set 7 | konch
# Processing Record 22 of Set 7 | tome-acu
# City not found. Skipping...
# Processing Record 23 of Set 7 | saint-francois
# Processing Record 24 of Set 7 | illela
# Processing Record 25 of Set 7 | ilulissat
# Processing Record 26 of Set 7 | cayenne
# Processing Record 27 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 7 | muros
# Processing Record 29 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 7 | moron
# Processing Record 31 of Set 7 | mecca
# Processing Record 32 of Set 7 | lorengau
# Processing Record 33 of Set 7 | port augusta
# Processing Record 34 of Set 7 | lompoc
# Processing Record 35 of Set 7 | naze
# Processing Record 36 of Set 7 | mariinskiy posad
# Processing Record 37 of Set 7 | belyy yar
# Processing Record 38 of Set 7 | rio grande
# Processing Record 39 of Set 7 | teguldet
# Processing Record 40 of Set 7 | tazovskiy
# Processing Record 41 of Set 7 | santa isabel
# Processing Record 42 of Set 7 | elverum
# Processing Record 43 of Set 7 | manta
# Processing Record 44 of Set 7 | port lincoln
# Processing Record 45 of Set 7 | tallahassee
# Processing Record 46 of Set 7 | garowe
# Processing Record 47 of Set 7 | kannad
# Processing Record 48 of Set 7 | opuwo
# Processing Record 49 of Set 7 | evora
# Processing Record 0 of Set 8 | puerto colombia
# Processing Record 1 of Set 8 | upata
# Processing Record 2 of Set 8 | saint-medard-en-jalles
# Processing Record 3 of Set 8 | prince albert
# Processing Record 4 of Set 8 | slave lake
# Processing Record 5 of Set 8 | provideniya
# Processing Record 6 of Set 8 | klaksvik
# Processing Record 7 of Set 8 | severomuysk
# Processing Record 8 of Set 8 | arraial do cabo
# Processing Record 9 of Set 8 | paita
# Processing Record 10 of Set 8 | churapcha
# Processing Record 11 of Set 8 | la palma
# Processing Record 12 of Set 8 | srednekolymsk
# Processing Record 13 of Set 8 | okhotsk
# Processing Record 14 of Set 8 | tahoua
# Processing Record 15 of Set 8 | orda
# Processing Record 16 of Set 8 | kushikino
# Processing Record 17 of Set 8 | kandy
# Processing Record 18 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 8 | zaozerne
# Processing Record 20 of Set 8 | huarmey
# Processing Record 21 of Set 8 | nabire
# Processing Record 22 of Set 8 | santa cruz
# Processing Record 23 of Set 8 | palasa
# Processing Record 24 of Set 8 | kahului
# Processing Record 25 of Set 8 | douglas
# Processing Record 26 of Set 8 | kavieng
# Processing Record 27 of Set 8 | onega
# Processing Record 28 of Set 8 | burayevo
# Processing Record 29 of Set 8 | uyemskiy
# Processing Record 30 of Set 8 | te anau
# Processing Record 31 of Set 8 | penha
# Processing Record 32 of Set 8 | azare
# Processing Record 33 of Set 8 | paramonga
# Processing Record 34 of Set 8 | batagay-alyta
# Processing Record 35 of Set 8 | leh
# Processing Record 36 of Set 8 | labuhan
# Processing Record 37 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 8 | necochea
# Processing Record 39 of Set 8 | marrakesh
# Processing Record 40 of Set 8 | san patricio
# Processing Record 41 of Set 8 | shelburne
# Processing Record 42 of Set 8 | stornoway
# Processing Record 43 of Set 8 | mananjary
# Processing Record 44 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 8 | horki
# Processing Record 46 of Set 8 | kimbe
# Processing Record 47 of Set 8 | susanville
# Processing Record 48 of Set 8 | contai
# Processing Record 49 of Set 8 | vestmannaeyjar
# Processing Record 0 of Set 9 | balabac
# Processing Record 1 of Set 9 | vanimo
# Processing Record 2 of Set 9 | elizabeth city
# Processing Record 3 of Set 9 | gizo
# Processing Record 4 of Set 9 | sidney
# Processing Record 5 of Set 9 | ventspils
# Processing Record 6 of Set 9 | husavik
# Processing Record 7 of Set 9 | umm ruwabah
# City not found. Skipping...
# Processing Record 8 of Set 9 | almaznyy
# Processing Record 9 of Set 9 | imbituba
# Processing Record 10 of Set 9 | hobyo
# Processing Record 11 of Set 9 | gimli
# Processing Record 12 of Set 9 | hervey bay
# Processing Record 13 of Set 9 | hammerfest
# Processing Record 14 of Set 9 | bourail
# Processing Record 15 of Set 9 | athens
# Processing Record 16 of Set 9 | piuma
# Processing Record 17 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 9 | kuybyshevo
# Processing Record 19 of Set 9 | vilhena
# Processing Record 20 of Set 9 | charagua
# Processing Record 21 of Set 9 | havoysund
# Processing Record 22 of Set 9 | vila
# Processing Record 23 of Set 9 | port angeles
# Processing Record 24 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 25 of Set 9 | pringsewu
# Processing Record 26 of Set 9 | nusaybin
# Processing Record 27 of Set 9 | brigantine
# Processing Record 28 of Set 9 | mandalgovi
# Processing Record 29 of Set 9 | manbij
# Processing Record 30 of Set 9 | hualmay
# Processing Record 31 of Set 9 | albacete
# Processing Record 32 of Set 9 | bilma
# Processing Record 33 of Set 9 | dolores
# Processing Record 34 of Set 9 | sal rei
# Processing Record 35 of Set 9 | roma
# Processing Record 36 of Set 9 | benguela
# Processing Record 37 of Set 9 | boke
# Processing Record 38 of Set 9 | hailey
# Processing Record 39 of Set 9 | inhambane
# Processing Record 40 of Set 9 | igrim
# Processing Record 41 of Set 9 | zyryanka
# Processing Record 42 of Set 9 | karratha
# Processing Record 43 of Set 9 | clyde river
# Processing Record 44 of Set 9 | bafia
# Processing Record 45 of Set 9 | panguma
# Processing Record 46 of Set 9 | rechitsy
# Processing Record 47 of Set 9 | halifax
# Processing Record 48 of Set 9 | novyy svit
# Processing Record 49 of Set 9 | korem
# Processing Record 0 of Set 10 | thompson
# Processing Record 1 of Set 10 | langarud
# Processing Record 2 of Set 10 | houma
# Processing Record 3 of Set 10 | ban nahin
# Processing Record 4 of Set 10 | soyo
# Processing Record 5 of Set 10 | altamira
# Processing Record 6 of Set 10 | tuatapere
# Processing Record 7 of Set 10 | skoghall
# Processing Record 8 of Set 10 | conde
# Processing Record 9 of Set 10 | fairbanks
# Processing Record 10 of Set 10 | dabakala
# Processing Record 11 of Set 10 | fortuna
# Processing Record 12 of Set 10 | zhitikara
# City not found. Skipping...
# Processing Record 13 of Set 10 | amahai
# Processing Record 14 of Set 10 | baruun-urt
# Processing Record 15 of Set 10 | cobija
# Processing Record 16 of Set 10 | henties bay
# Processing Record 17 of Set 10 | mount isa
# Processing Record 18 of Set 10 | thinadhoo
# Processing Record 19 of Set 10 | morro bay
# Processing Record 20 of Set 10 | itarema
# Processing Record 21 of Set 10 | fereydunshahr
# Processing Record 22 of Set 10 | cavite
# Processing Record 23 of Set 10 | bocaranga
# City not found. Skipping...
# Processing Record 24 of Set 10 | witrivier
# City not found. Skipping...
# Processing Record 25 of Set 10 | paamiut
# Processing Record 26 of Set 10 | khandbari
# Processing Record 27 of Set 10 | shatrovo
# Processing Record 28 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 10 | taupo
# Processing Record 30 of Set 10 | barra do garcas
# Processing Record 31 of Set 10 | kantunilkin
# Processing Record 32 of Set 10 | hami
# Processing Record 33 of Set 10 | banjar
# Processing Record 34 of Set 10 | jutai
# Processing Record 35 of Set 10 | coquimbo
# Processing Record 36 of Set 10 | camp verde
# Processing Record 37 of Set 10 | zyryanovsk
# Processing Record 38 of Set 10 | jieshi
# Processing Record 39 of Set 10 | gazanjyk
# Processing Record 40 of Set 10 | port-gentil
# Processing Record 41 of Set 10 | acarau
# Processing Record 42 of Set 10 | guanica
# Processing Record 43 of Set 10 | ladario
# Processing Record 44 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 45 of Set 10 | severo-kurilsk
# Processing Record 46 of Set 10 | lalsk
# Processing Record 47 of Set 10 | guerrero negro
# Processing Record 48 of Set 10 | olga
# Processing Record 49 of Set 10 | preobrazheniye
# Processing Record 0 of Set 11 | nizhniy baskunchak
# Processing Record 1 of Set 11 | crotone
# Processing Record 2 of Set 11 | pemangkat
# Processing Record 3 of Set 11 | angoche
# Processing Record 4 of Set 11 | meulaboh
# Processing Record 5 of Set 11 | tateyama
# Processing Record 6 of Set 11 | mayumba
# Processing Record 7 of Set 11 | wattegama
# Processing Record 8 of Set 11 | majene
# Processing Record 9 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 11 | singapore
# Processing Record 11 of Set 11 | caucaia
# Processing Record 12 of Set 11 | alugan
# Processing Record 13 of Set 11 | tucurui
# Processing Record 14 of Set 11 | riyadh
# Processing Record 15 of Set 11 | tagusao
# Processing Record 16 of Set 11 | kudahuvadhoo
# Processing Record 17 of Set 11 | loubomo
# Processing Record 18 of Set 11 | betioky
# Processing Record 19 of Set 11 | duluth
# Processing Record 20 of Set 11 | kajiado
# Processing Record 21 of Set 11 | bathsheba
# Processing Record 22 of Set 11 | saint-ambroise
# Processing Record 23 of Set 11 | vitim
# Processing Record 24 of Set 11 | quchan
# Processing Record 25 of Set 11 | saint-joseph
# Processing Record 26 of Set 11 | baykit
# Processing Record 27 of Set 11 | noumea
# Processing Record 28 of Set 11 | yefira
# City not found. Skipping...
# Processing Record 29 of Set 11 | araouane
# Processing Record 30 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 11 | kurilsk
# Processing Record 32 of Set 11 | codrington
# Processing Record 33 of Set 11 | bintulu
# Processing Record 34 of Set 11 | keti bandar
# Processing Record 35 of Set 11 | laguna
# Processing Record 36 of Set 11 | aksarka
# Processing Record 37 of Set 11 | caravelas
# Processing Record 38 of Set 11 | banda aceh
# Processing Record 39 of Set 11 | esperance
# Processing Record 40 of Set 11 | roebourne
# Processing Record 41 of Set 11 | mizdah
# Processing Record 42 of Set 11 | coahuayana
# Processing Record 43 of Set 11 | islahiye
# Processing Record 44 of Set 11 | tura
# Processing Record 45 of Set 11 | sabang
# Processing Record 46 of Set 11 | muli
# Processing Record 47 of Set 11 | dombarovskiy
# Processing Record 48 of Set 11 | buritama
# Processing Record 49 of Set 11 | port pirie
# Processing Record 0 of Set 12 | jacareacanga
# Processing Record 1 of Set 12 | nyagan
# Processing Record 2 of Set 12 | gat
# Processing Record 3 of Set 12 | mombetsu
# Processing Record 4 of Set 12 | hamina
# Processing Record 5 of Set 12 | sun valley
# Processing Record 6 of Set 12 | westport
# Processing Record 7 of Set 12 | santa rosa
# Processing Record 8 of Set 12 | krasnoyarskaya
# Processing Record 9 of Set 12 | bairiki
# Processing Record 10 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 11 of Set 12 | kalanguy
# Processing Record 12 of Set 12 | othonoi
# City not found. Skipping...
# Processing Record 13 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 12 | hollins
# Processing Record 15 of Set 12 | kaseda
# Processing Record 16 of Set 12 | samarai
# Processing Record 17 of Set 12 | merke
# Processing Record 18 of Set 12 | zimovniki
# Processing Record 19 of Set 12 | doha
# Processing Record 20 of Set 12 | caiaponia
# Processing Record 21 of Set 12 | chautla
# City not found. Skipping...
# Processing Record 22 of Set 12 | sicamous
# Processing Record 23 of Set 12 | lata
# Processing Record 24 of Set 12 | waw
# Processing Record 25 of Set 12 | bestobe
# Processing Record 26 of Set 12 | asosa
# Processing Record 27 of Set 12 | seoul
# Processing Record 28 of Set 12 | alamos
# Processing Record 29 of Set 12 | pekalongan
# Processing Record 30 of Set 12 | teya
# Processing Record 31 of Set 12 | pundaguitan
# Processing Record 32 of Set 12 | dawlatabad
# Processing Record 33 of Set 12 | plettenberg bay
# Processing Record 34 of Set 12 | komsomolskiy
# Processing Record 35 of Set 12 | jiazi
# Processing Record 36 of Set 12 | ningbo
# Processing Record 37 of Set 12 | qui nhon
# Processing Record 38 of Set 12 | bubaque
# Processing Record 39 of Set 12 | comodoro rivadavia
# Processing Record 40 of Set 12 | adre
# Processing Record 41 of Set 12 | quesnel
# Processing Record 42 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 12 | popondetta
# Processing Record 44 of Set 12 | tonantins
# Processing Record 45 of Set 12 | pleasanton
# Processing Record 46 of Set 12 | gorontalo
# Processing Record 47 of Set 12 | eyl
# Processing Record 48 of Set 12 | humberto de campos
# Processing Record 49 of Set 12 | yatou
# Processing Record 0 of Set 13 | kelo
# Processing Record 1 of Set 13 | akureyri
# Processing Record 2 of Set 13 | mount gambier
# Processing Record 3 of Set 13 | sorland
# Processing Record 4 of Set 13 | sumbawanga
# Processing Record 5 of Set 13 | xai-xai
# Processing Record 6 of Set 13 | bhagalpur
# Processing Record 7 of Set 13 | dujuma
# City not found. Skipping...
# Processing Record 8 of Set 13 | oga
# Processing Record 9 of Set 13 | cam pha
# City not found. Skipping...
# Processing Record 10 of Set 13 | wencheng
# Processing Record 11 of Set 13 | payson
# Processing Record 12 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 13 | pombia
# Processing Record 14 of Set 13 | antofagasta
# Processing Record 15 of Set 13 | batticaloa
# Processing Record 16 of Set 13 | saldanha
# Processing Record 17 of Set 13 | waipawa
# Processing Record 18 of Set 13 | road town
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    ushuaia -54.8000  -68.3000     14.79        51           4        4.74
# 1     juybar  36.6412   52.9124      7.82        54         100        1.80
# 2    batagay  67.6333  134.6333    -44.43        96          99        0.96
# 3      kapaa  22.0752 -159.3190     25.18        68          40        8.23
# 4  upernavik  72.7868  -56.1549    -18.94        95         100        4.22
#
#   Country        Date
# 0      AR  1674940233
# 1      IR  1674940234
# 2      RU  1674940235
# 3      US  1674940235
# 4      GL  1674940236

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          ushuaia -54.8000  -68.3000     14.79        51           4
# 1           juybar  36.6412   52.9124      7.82        54         100
# 2          batagay  67.6333  134.6333    -44.43        96          99
# 3            kapaa  22.0752 -159.3190     25.18        68          40
# 4        upernavik  72.7868  -56.1549    -18.94        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.74      AR  1674940233
# 1              1.80      IR  1674940234
# 2              0.96      RU  1674940235
# 3              8.23      US  1674940235
# 4              4.22      GL  1674940236

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Format date
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           juybar  36.6412   52.9124      7.82        54         100
# 2          batagay  67.6333  134.6333    -44.43        96          99
# 3            kapaa  22.0752 -159.3190     25.18        68          40
# 4        upernavik  72.7868  -56.1549    -18.94        95         100
# 5        jamestown  42.0970  -79.2353      2.80        51           0
#
#          Wind Speed Country        Date
# City_ID
# 1              1.80      IR  1674940234
# 2              0.96      RU  1674940235
# 3              8.23      US  1674940235
# 4              4.22      GL  1674940236
# 5              5.14      US  1674940231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          ushuaia -54.8000  -68.3000     14.79        51           4
# 7        cape town -33.9258   18.4232     18.40        58           0
# 9           forbes -33.3833  148.0167     28.84        37         100
# 10         rikitea -23.1203 -134.9692     25.53        76          34
# 11         iquitos  -3.7481  -73.2472     31.02        66          40
#
#          Wind Speed Country        Date
# City_ID
# 0              4.74      AR  1674940233
# 7              9.77      ZA  1674939569
# 9              2.27      AU  1674940238
# 10             5.65      PF  1674940238
# 11             1.54      PE  1674940239

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a negative relationship between temperature and latitude")
print("In the northern hemisphere, as the latitude increases the distance from the equator increases")
print("As you move away from the equator, the max temperature decreases.")
# Out:
# The r-value is -0.8329000349618159
# The regression displays a negative relationship between temperature and latitude
# In the northern hemisphere, as the latitude increases the distance from the equator increases
# As you move away from the equator, the max temperature decreases.

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a sligtly positive relationship between temperature and latitude.")
print("In the southern hemisphere, as the latitude increases the distance from the equator decreases")
print("As you move closer to the equator, the max temperature generally increases.")
# Out:
# The r-value is 0.42770663332184317
# -----------------------------------
# Observations about linear relationship:
# The regression displays a sligtly positive relationship between temperature and latitude.
# In the southern hemisphere, as the latitude increases the distance from the equator decreases
# As you move closer to the equator, the max temperature generally increases.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
# Out:
# The r-value is 0.41816746227536455
# -----------------------------------
# Observations about linear relationship:

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
# Out:
# The r-value is 0.4348716041107429
# -----------------------------------
# Observations about linear relationship:

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
# Out:
# The r-value is 0.20221643423042887
# -----------------------------------
# Observations about linear relationship:

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
# Out:
# The r-value is 0.26169232264358167
# -----------------------------------
# Observations about linear relationship:

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
# Out:
# The r-value is 0.03143348921256655
# -----------------------------------
# Observations about linear relationship:

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
# Out:
# The r-value is -0.3391265032402671
# -----------------------------------
# Observations about linear relationship:

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 620

# %%
#Set units for search
units = "metric"

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | san carlos de bariloche
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | souillac
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | cherskiy
# Processing Record 11 of Set 1 | san cristobal
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | sorland
# Processing Record 14 of Set 1 | constitucion
# Processing Record 15 of Set 1 | pevek
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | bairiki
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | merrill
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | chapais
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | jining
# Processing Record 27 of Set 1 | provideniya
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | snasa
# Processing Record 31 of Set 1 | alta floresta
# Processing Record 32 of Set 1 | brodokalmak
# Processing Record 33 of Set 1 | kapoeta
# Processing Record 34 of Set 1 | kirkwall
# Processing Record 35 of Set 1 | harper
# Processing Record 36 of Set 1 | north myrtle beach
# Processing Record 37 of Set 1 | pekan
# Processing Record 38 of Set 1 | marsh harbour
# Processing Record 39 of Set 1 | hamilton
# Processing Record 40 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 1 | dawson creek
# Processing Record 42 of Set 1 | jawhar
# Processing Record 43 of Set 1 | deming
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | caxito
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | touros
# Processing Record 48 of Set 1 | grindavik
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | luderitz
# Processing Record 0 of Set 2 | kidal
# Processing Record 1 of Set 2 | ust-koksa
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | bilma
# Processing Record 5 of Set 2 | yulara
# Processing Record 6 of Set 2 | craigieburn
# Processing Record 7 of Set 2 | yumen
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | magistralnyy
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | valle hermoso
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | faanui
# Processing Record 15 of Set 2 | lompoc
# Processing Record 16 of Set 2 | bethanien
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | mercedes
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 21 of Set 2 | seoul
# Processing Record 22 of Set 2 | abu samrah
# Processing Record 23 of Set 2 | biak
# Processing Record 24 of Set 2 | sarany
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | beloha
# Processing Record 27 of Set 2 | isangel
# Processing Record 28 of Set 2 | college
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | orocue
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | mumbwa
# Processing Record 35 of Set 2 | phonhong
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | ponta do sol
# Processing Record 39 of Set 2 | paka
# Processing Record 40 of Set 2 | karasjok
# Processing Record 41 of Set 2 | sitka
# Processing Record 42 of Set 2 | san quintin
# Processing Record 43 of Set 2 | saravan
# Processing Record 44 of Set 2 | vestmannaeyjar
# Processing Record 45 of Set 2 | brae
# Processing Record 46 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 2 | ritchie
# Processing Record 48 of Set 2 | zyryanka
# Processing Record 49 of Set 2 | victoria
# Processing Record 0 of Set 3 | fairbanks
# Processing Record 1 of Set 3 | solano
# Processing Record 2 of Set 3 | rio gallegos
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | pocosol
# Processing Record 5 of Set 3 | kuito
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | longyearbyen
# Processing Record 8 of Set 3 | lewistown
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | ghanzi
# Processing Record 11 of Set 3 | buala
# Processing Record 12 of Set 3 | yinchuan
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | maldonado
# Processing Record 16 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | bengkulu
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | zhanakorgan
# Processing Record 21 of Set 3 | norrtalje
# Processing Record 22 of Set 3 | quang ngai
# Processing Record 23 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 3 | sur
# Processing Record 25 of Set 3 | comodoro rivadavia
# Processing Record 26 of Set 3 | san ramon
# Processing Record 27 of Set 3 | evensk
# Processing Record 28 of Set 3 | ossora
# Processing Record 29 of Set 3 | talnakh
# Processing Record 30 of Set 3 | dikson
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | kaeo
# Processing Record 33 of Set 3 | ahipara
# Processing Record 34 of Set 3 | hofn
# Processing Record 35 of Set 3 | haines junction
# Processing Record 36 of Set 3 | kuala lipis
# Processing Record 37 of Set 3 | bethel
# Processing Record 38 of Set 3 | diamantino
# Processing Record 39 of Set 3 | bathsheba
# Processing Record 40 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 3 | puerto colombia
# Processing Record 42 of Set 3 | dapaong
# Processing Record 43 of Set 3 | labuhan
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | micheweni
# Processing Record 46 of Set 3 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 47 of Set 3 | horqueta
# Processing Record 48 of Set 3 | codrington
# Processing Record 49 of Set 3 | odweyne
# Processing Record 0 of Set 4 | ulaangom
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | kisaran
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | buzmeyin
# Processing Record 5 of Set 4 | martapura
# Processing Record 6 of Set 4 | butka
# Processing Record 7 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 4 | launceston
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | nigel
# Processing Record 12 of Set 4 | torbay
# Processing Record 13 of Set 4 | xuddur
# Processing Record 14 of Set 4 | kavieng
# Processing Record 15 of Set 4 | ixtapa
# Processing Record 16 of Set 4 | ilulissat
# Processing Record 17 of Set 4 | atambua
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | matara
# Processing Record 20 of Set 4 | uvat
# Processing Record 21 of Set 4 | mana
# Processing Record 22 of Set 4 | atuona
# Processing Record 23 of Set 4 | harindanga
# Processing Record 24 of Set 4 | peniche
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | airai
# Processing Record 27 of Set 4 | bereda
# Processing Record 28 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | caloundra
# Processing Record 32 of Set 4 | acapulco
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | damaturu
# Processing Record 35 of Set 4 | suntar
# Processing Record 36 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 4 | simao
# Processing Record 38 of Set 4 | fukue
# Processing Record 39 of Set 4 | bergen
# Processing Record 40 of Set 4 | adrar
# Processing Record 41 of Set 4 | asau
# Processing Record 42 of Set 4 | roald
# Processing Record 43 of Set 4 | svetlogorsk
# Processing Record 44 of Set 4 | hobyo
# Processing Record 45 of Set 4 | kondopoga
# Processing Record 46 of Set 4 | kuching
# Processing Record 47 of Set 4 | dumas
# Processing Record 48 of Set 4 | kungurtug
# Processing Record 49 of Set 4 | port said
# Processing Record 0 of Set 5 | lagoa
# Processing Record 1 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | selfoss
# Processing Record 6 of Set 5 | itaquyry
# Processing Record 7 of Set 5 | pandan
# Processing Record 8 of Set 5 | jos
# Processing Record 9 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 5 | yarada
# Processing Record 11 of Set 5 | christchurch
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | daru
# Processing Record 14 of Set 5 | kyaukse
# Processing Record 15 of Set 5 | suvorovo
# Processing Record 16 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 5 | san patricio
# Processing Record 18 of Set 5 | chokurdakh
# Processing Record 19 of Set 5 | hirara
# Processing Record 20 of Set 5 | hay river
# Processing Record 21 of Set 5 | acarau
# Processing Record 22 of Set 5 | chanal
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | nikolskoye
# Processing Record 25 of Set 5 | vila
# Processing Record 26 of Set 5 | apastovo
# Processing Record 27 of Set 5 | udachnyy
# Processing Record 28 of Set 5 | soto la marina
# Processing Record 29 of Set 5 | tanout
# Processing Record 30 of Set 5 | miyang
# Processing Record 31 of Set 5 | shumikha
# Processing Record 32 of Set 5 | kupang
# Processing Record 33 of Set 5 | waipawa
# Processing Record 34 of Set 5 | solomenskoye
# Processing Record 35 of Set 5 | burns lake
# Processing Record 36 of Set 5 | riyadh
# Processing Record 37 of Set 5 | makakilo city
# Processing Record 38 of Set 5 | pangnirtung
# Processing Record 39 of Set 5 | port lincoln
# Processing Record 40 of Set 5 | okha
# Processing Record 41 of Set 5 | fuxin
# Processing Record 42 of Set 5 | kavaratti
# Processing Record 43 of Set 5 | muroto
# Processing Record 44 of Set 5 | bereznehuvate
# Processing Record 45 of Set 5 | high level
# Processing Record 46 of Set 5 | erzin
# Processing Record 47 of Set 5 | moree
# Processing Record 48 of Set 5 | grajau
# Processing Record 49 of Set 5 | yellowknife
# Processing Record 0 of Set 6 | kaseda
# Processing Record 1 of Set 6 | dunedin
# Processing Record 2 of Set 6 | burnie
# Processing Record 3 of Set 6 | oktyabrskiy
# Processing Record 4 of Set 6 | athabasca
# Processing Record 5 of Set 6 | tiksi
# Processing Record 6 of Set 6 | chokwe
# Processing Record 7 of Set 6 | tual
# Processing Record 8 of Set 6 | vilyuysk
# Processing Record 9 of Set 6 | dryden
# Processing Record 10 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 11 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 6 | kampene
# Processing Record 13 of Set 6 | hohhot
# Processing Record 14 of Set 6 | vysokogornyy
# Processing Record 15 of Set 6 | keetmanshoop
# Processing Record 16 of Set 6 | mayumba
# Processing Record 17 of Set 6 | zaysan
# Processing Record 18 of Set 6 | saiha
# Processing Record 19 of Set 6 | talakan
# Processing Record 20 of Set 6 | nokaneng
# Processing Record 21 of Set 6 | znamenskoye
# Processing Record 22 of Set 6 | marsa matruh
# Processing Record 23 of Set 6 | dzilam gonzalez
# Processing Record 24 of Set 6 | ndola
# Processing Record 25 of Set 6 | beira
# Processing Record 26 of Set 6 | ubinskoye
# Processing Record 27 of Set 6 | esperance
# Processing Record 28 of Set 6 | moa
# Processing Record 29 of Set 6 | nelson bay
# Processing Record 30 of Set 6 | prince george
# Processing Record 31 of Set 6 | elko
# Processing Record 32 of Set 6 | burgersdorp
# Processing Record 33 of Set 6 | ulverstone
# Processing Record 34 of Set 6 | lipari
# Processing Record 35 of Set 6 | buchanan
# Processing Record 36 of Set 6 | kota bahru
# Processing Record 37 of Set 6 | balgazyn
# Processing Record 38 of Set 6 | aripuana
# Processing Record 39 of Set 6 | atar
# Processing Record 40 of Set 6 | lebu
# Processing Record 41 of Set 6 | mangan
# Processing Record 42 of Set 6 | nagua
# Processing Record 43 of Set 6 | tuktoyaktuk
# Processing Record 44 of Set 6 | gubskaya
# Processing Record 45 of Set 6 | alofi
# Processing Record 46 of Set 6 | bloomingdale
# Processing Record 47 of Set 6 | mackay
# Processing Record 48 of Set 6 | kijang
# Processing Record 49 of Set 6 | aklavik
# Processing Record 0 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 7 | pyapon
# Processing Record 2 of Set 7 | olafsvik
# Processing Record 3 of Set 7 | brigantine
# Processing Record 4 of Set 7 | linxia
# Processing Record 5 of Set 7 | narsaq
# Processing Record 6 of Set 7 | finnsnes
# Processing Record 7 of Set 7 | flin flon
# Processing Record 8 of Set 7 | klyuchi
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | bonavista
# Processing Record 11 of Set 7 | yaring
# Processing Record 12 of Set 7 | kahului
# Processing Record 13 of Set 7 | avera
# Processing Record 14 of Set 7 | russell
# Processing Record 15 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 16 of Set 7 | broken hill
# Processing Record 17 of Set 7 | coihaique
# Processing Record 18 of Set 7 | nouadhibou
# Processing Record 19 of Set 7 | vardo
# Processing Record 20 of Set 7 | yarim
# Processing Record 21 of Set 7 | mandiana
# Processing Record 22 of Set 7 | enger
# Processing Record 23 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 24 of Set 7 | muriwai beach
# Processing Record 25 of Set 7 | kholm
# Processing Record 26 of Set 7 | mweka
# Processing Record 27 of Set 7 | balkhash
# Processing Record 28 of Set 7 | sembe
# Processing Record 29 of Set 7 | lavrentiya
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | lebedinyy
# Processing Record 32 of Set 7 | safidon
# Processing Record 33 of Set 7 | wick
# Processing Record 34 of Set 7 | vao
# Processing Record 35 of Set 7 | ancud
# Processing Record 36 of Set 7 | kurumkan
# Processing Record 37 of Set 7 | kununurra
# Processing Record 38 of Set 7 | amazar
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 7 | gladstone
# Processing Record 42 of Set 7 | antigonish
# Processing Record 43 of Set 7 | shache
# Processing Record 44 of Set 7 | coolum beach
# Processing Record 45 of Set 7 | ostrovnoy
# Processing Record 46 of Set 7 | genhe
# Processing Record 47 of Set 7 | guerrero negro
# Processing Record 48 of Set 7 | lucea
# Processing Record 49 of Set 7 | nanortalik
# Processing Record 0 of Set 8 | impfondo
# Processing Record 1 of Set 8 | hutchinson
# Processing Record 2 of Set 8 | vanavara
# Processing Record 3 of Set 8 | saint-augustin
# Processing Record 4 of Set 8 | puerto narino
# Processing Record 5 of Set 8 | sao filipe
# Processing Record 6 of Set 8 | prince rupert
# Processing Record 7 of Set 8 | tolon
# Processing Record 8 of Set 8 | kalmunai
# Processing Record 9 of Set 8 | harsin
# Processing Record 10 of Set 8 | garliava
# Processing Record 11 of Set 8 | valkeala
# Processing Record 12 of Set 8 | kletskaya
# Processing Record 13 of Set 8 | hasaki
# Processing Record 14 of Set 8 | mount isa
# Processing Record 15 of Set 8 | tuatapere
# Processing Record 16 of Set 8 | ripon
# Processing Record 17 of Set 8 | kruisfontein
# Processing Record 18 of Set 8 | severnyy
# Processing Record 19 of Set 8 | benguela
# Processing Record 20 of Set 8 | te anau
# Processing Record 21 of Set 8 | vila franca do campo
# Processing Record 22 of Set 8 | pizhma
# Processing Record 23 of Set 8 | husavik
# Processing Record 24 of Set 8 | port hardy
# Processing Record 25 of Set 8 | razole
# Processing Record 26 of Set 8 | nurota
# Processing Record 27 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 8 | sisimiut
# Processing Record 29 of Set 8 | doha
# Processing Record 30 of Set 8 | geraldton
# Processing Record 31 of Set 8 | tecolutla
# Processing Record 32 of Set 8 | poum
# Processing Record 33 of Set 8 | caronport
# Processing Record 34 of Set 8 | biskamzha
# Processing Record 35 of Set 8 | caravelas
# Processing Record 36 of Set 8 | mangai
# Processing Record 37 of Set 8 | soyaux
# Processing Record 38 of Set 8 | enid
# Processing Record 39 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 8 | talaya
# Processing Record 42 of Set 8 | kondol
# Processing Record 43 of Set 8 | surgut
# Processing Record 44 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 45 of Set 8 | road town
# Processing Record 46 of Set 8 | bloemhof
# Processing Record 47 of Set 8 | rajkot
# Processing Record 48 of Set 8 | carson city
# Processing Record 49 of Set 8 | ahuimanu
# Processing Record 0 of Set 9 | puerto carreno
# Processing Record 1 of Set 9 | susangerd
# Processing Record 2 of Set 9 | mirnyy
# Processing Record 3 of Set 9 | ayagoz
# Processing Record 4 of Set 9 | abha
# Processing Record 5 of Set 9 | maceio
# Processing Record 6 of Set 9 | komsomolskiy
# Processing Record 7 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 8 of Set 9 | kayerkan
# Processing Record 9 of Set 9 | shingu
# Processing Record 10 of Set 9 | gambela
# Processing Record 11 of Set 9 | lac du bonnet
# Processing Record 12 of Set 9 | los llanos de aridane
# Processing Record 13 of Set 9 | yining
# Processing Record 14 of Set 9 | zhangye
# Processing Record 15 of Set 9 | alugan
# Processing Record 16 of Set 9 | jasper
# Processing Record 17 of Set 9 | watsa
# Processing Record 18 of Set 9 | teneguiban
# City not found. Skipping...
# Processing Record 19 of Set 9 | panalingaan
# Processing Record 20 of Set 9 | sioux lookout
# Processing Record 21 of Set 9 | tocopilla
# Processing Record 22 of Set 9 | carballo
# Processing Record 23 of Set 9 | talcahuano
# Processing Record 24 of Set 9 | pechora
# Processing Record 25 of Set 9 | korla
# Processing Record 26 of Set 9 | manali
# Processing Record 27 of Set 9 | basyanovskiy
# City not found. Skipping...
# Processing Record 28 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 9 | banda aceh
# Processing Record 30 of Set 9 | east london
# Processing Record 31 of Set 9 | marawi
# Processing Record 32 of Set 9 | vanimo
# Processing Record 33 of Set 9 | nosy varika
# Processing Record 34 of Set 9 | port macquarie
# Processing Record 35 of Set 9 | alice springs
# Processing Record 36 of Set 9 | coahuayana
# Processing Record 37 of Set 9 | kadnikov
# Processing Record 38 of Set 9 | grand gaube
# Processing Record 39 of Set 9 | mount gambier
# Processing Record 40 of Set 9 | boralday
# Processing Record 41 of Set 9 | naze
# Processing Record 42 of Set 9 | kempele
# Processing Record 43 of Set 9 | tilichiki
# Processing Record 44 of Set 9 | malakal
# Processing Record 45 of Set 9 | rawson
# Processing Record 46 of Set 9 | piste
# Processing Record 47 of Set 9 | tungor
# Processing Record 48 of Set 9 | altoona
# Processing Record 49 of Set 9 | uddevalla
# Processing Record 0 of Set 10 | cidreira
# Processing Record 1 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 2 of Set 10 | sar-e pul
# Processing Record 3 of Set 10 | bam
# Processing Record 4 of Set 10 | bambous virieux
# Processing Record 5 of Set 10 | port augusta
# Processing Record 6 of Set 10 | hashtrud
# Processing Record 7 of Set 10 | tessalit
# Processing Record 8 of Set 10 | ilhabela
# Processing Record 9 of Set 10 | kudahuvadhoo
# Processing Record 10 of Set 10 | terney
# Processing Record 11 of Set 10 | lower hutt
# Processing Record 12 of Set 10 | kattivakkam
# Processing Record 13 of Set 10 | gorele
# Processing Record 14 of Set 10 | domna
# Processing Record 15 of Set 10 | rutland
# Processing Record 16 of Set 10 | derzhavinsk
# Processing Record 17 of Set 10 | ust-nera
# Processing Record 18 of Set 10 | felanitx
# Processing Record 19 of Set 10 | vallenar
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | bousse
# Processing Record 22 of Set 10 | pesaro
# Processing Record 23 of Set 10 | klaksvik
# Processing Record 24 of Set 10 | cairns
# Processing Record 25 of Set 10 | san vicente
# Processing Record 26 of Set 10 | cayenne
# Processing Record 27 of Set 10 | aksu
# Processing Record 28 of Set 10 | boa vista
# Processing Record 29 of Set 10 | ingham
# Processing Record 30 of Set 10 | anito
# Processing Record 31 of Set 10 | nicolas bravo
# Processing Record 32 of Set 10 | necochea
# Processing Record 33 of Set 10 | flambouron
# City not found. Skipping...
# Processing Record 34 of Set 10 | gat
# Processing Record 35 of Set 10 | itoman
# Processing Record 36 of Set 10 | padang
# Processing Record 37 of Set 10 | aykhal
# Processing Record 38 of Set 10 | stornoway
# Processing Record 39 of Set 10 | hervey bay
# Processing Record 40 of Set 10 | lorengau
# Processing Record 41 of Set 10 | zhezkazgan
# Processing Record 42 of Set 10 | lazaro cardenas
# Processing Record 43 of Set 10 | amroha
# Processing Record 44 of Set 10 | jaciara
# Processing Record 45 of Set 10 | colares
# Processing Record 46 of Set 10 | tarko-sale
# Processing Record 47 of Set 10 | qingdao
# Processing Record 48 of Set 10 | namibe
# Processing Record 49 of Set 10 | wanning
# Processing Record 0 of Set 11 | ikot ekpene
# Processing Record 1 of Set 11 | chaozhou
# Processing Record 2 of Set 11 | killam
# Processing Record 3 of Set 11 | elizabeth city
# Processing Record 4 of Set 11 | tura
# Processing Record 5 of Set 11 | formosa
# Processing Record 6 of Set 11 | sao miguel do araguaia
# Processing Record 7 of Set 11 | nemuro
# Processing Record 8 of Set 11 | faya
# Processing Record 9 of Set 11 | camacha
# Processing Record 10 of Set 11 | lata
# Processing Record 11 of Set 11 | scottsbluff
# Processing Record 12 of Set 11 | ishigaki
# Processing Record 13 of Set 11 | fushe-arrez
# Processing Record 14 of Set 11 | chumikan
# Processing Record 15 of Set 11 | back mountain
# Processing Record 16 of Set 11 | kloulklubed
# Processing Record 17 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 11 | dingle
# Processing Record 19 of Set 11 | richards bay
# Processing Record 20 of Set 11 | yamada
# Processing Record 21 of Set 11 | nioro
# Processing Record 22 of Set 11 | katsuura
# Processing Record 23 of Set 11 | lasa
# Processing Record 24 of Set 11 | nagato
# Processing Record 25 of Set 11 | callaway
# Processing Record 26 of Set 11 | qinzhou
# Processing Record 27 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 28 of Set 11 | katherine
# Processing Record 29 of Set 11 | borogontsy
# Processing Record 30 of Set 11 | palmer
# Processing Record 31 of Set 11 | tomatlan
# Processing Record 32 of Set 11 | cerrito
# Processing Record 33 of Set 11 | fort nelson
# Processing Record 34 of Set 11 | skibbereen
# Processing Record 35 of Set 11 | gbarnga
# Processing Record 36 of Set 11 | maues
# Processing Record 37 of Set 11 | akom
# Processing Record 38 of Set 11 | araguacu
# Processing Record 39 of Set 11 | mersing
# Processing Record 40 of Set 11 | cockburn town
# Processing Record 41 of Set 11 | freetown
# Processing Record 42 of Set 11 | ukiah
# Processing Record 43 of Set 11 | san fernando
# Processing Record 44 of Set 11 | union city
# Processing Record 45 of Set 11 | nadym
# Processing Record 46 of Set 11 | taywarah
# Processing Record 47 of Set 11 | zhigansk
# Processing Record 48 of Set 11 | kuusankoski
# Processing Record 49 of Set 11 | cortez
# Processing Record 0 of Set 12 | teresopolis
# Processing Record 1 of Set 12 | palmas bellas
# Processing Record 2 of Set 12 | cartagena del chaira
# Processing Record 3 of Set 12 | najran
# Processing Record 4 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 12 | shelburne
# Processing Record 6 of Set 12 | yaypan
# Processing Record 7 of Set 12 | miquelon
# Processing Record 8 of Set 12 | liverpool
# Processing Record 9 of Set 12 | bunia
# Processing Record 10 of Set 12 | huarmey
# Processing Record 11 of Set 12 | gunzenhausen
# Processing Record 12 of Set 12 | pak phanang
# Processing Record 13 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 14 of Set 12 | oudenburg
# Processing Record 15 of Set 12 | chara
# Processing Record 16 of Set 12 | tanah merah
# Processing Record 17 of Set 12 | south venice
# Processing Record 18 of Set 12 | andenes
# Processing Record 19 of Set 12 | muros
# Processing Record 20 of Set 12 | akyab
# Processing Record 21 of Set 12 | port hedland
# Processing Record 22 of Set 12 | clyde river
# Processing Record 23 of Set 12 | lalmohan
# Processing Record 24 of Set 12 | kieta
# Processing Record 25 of Set 12 | bandarbeyla
# Processing Record 26 of Set 12 | am timan
# Processing Record 27 of Set 12 | copiapo
# Processing Record 28 of Set 12 | la ronge
# Processing Record 29 of Set 12 | meadow lake
# Processing Record 30 of Set 12 | rocha
# Processing Record 31 of Set 12 | balabac
# Processing Record 32 of Set 12 | taoudenni
# Processing Record 33 of Set 12 | lebyazhye
# Processing Record 34 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 12 | ahar
# Processing Record 36 of Set 12 | jurm
# Processing Record 37 of Set 12 | baiao
# Processing Record 38 of Set 12 | ambilobe
# Processing Record 39 of Set 12 | urumqi
# Processing Record 40 of Set 12 | evanston
# Processing Record 41 of Set 12 | dubrovka
# Processing Record 42 of Set 12 | ust-ilimsk
# Processing Record 43 of Set 12 | cabra
# Processing Record 44 of Set 12 | celestun
# Processing Record 45 of Set 12 | lubu
# Processing Record 46 of Set 12 | nyurba
# Processing Record 47 of Set 12 | saint anthony
# Processing Record 48 of Set 12 | inta
# Processing Record 49 of Set 12 | esna
# Processing Record 0 of Set 13 | naifaru
# Processing Record 1 of Set 13 | itaituba
# Processing Record 2 of Set 13 | marivan
# Processing Record 3 of Set 13 | port blair
# Processing Record 4 of Set 13 | pandamatenga
# Processing Record 5 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 13 | paamiut
# Processing Record 7 of Set 13 | vani
# Processing Record 8 of Set 13 | mushie
# Processing Record 9 of Set 13 | susanville
# Processing Record 10 of Set 13 | ayna
# Processing Record 11 of Set 13 | naco
# Processing Record 12 of Set 13 | inhambane
# Processing Record 13 of Set 13 | la crosse
# Processing Record 14 of Set 13 | henties bay
# Processing Record 15 of Set 13 | beringovskiy
# Processing Record 16 of Set 13 | marshall
# Processing Record 17 of Set 13 | margate
# Processing Record 18 of Set 13 | severodvinsk
# Processing Record 19 of Set 13 | weinan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                   albany  42.6001  -73.9662      6.48        72         100
# 1  san carlos de bariloche -41.1456  -71.3082     21.86        40          20
# 2                   hobart -42.8794  147.3294     25.03        53          40
# 3                    vaini -21.2000 -175.2000     29.09        84          40
# 4                 souillac -20.5167   57.5167     23.21        94          20
#
#    Wind Speed Country        Date
# 0        1.34      US  1675042085
# 1       10.29      AR  1675042086
# 2        2.57      AU  1675041994
# 3        3.60      TO  1675042000
# 4        1.54      MU  1675042055

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                             City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                         albany  42.6001  -73.9662      6.48        72
# 1        san carlos de bariloche -41.1456  -71.3082     21.86        40
# 2                         hobart -42.8794  147.3294     25.03        53
# 3                          vaini -21.2000 -175.2000     29.09        84
# 4                       souillac -20.5167   57.5167     23.21        94
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        1.34      US  1675042085
# 1                20       10.29      AR  1675042086
# 2                40        2.57      AU  1675041994
# 3                40        3.60      TO  1675042000
# 4                20        1.54      MU  1675042055

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Format date
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               albany  42.6001  -73.9662      6.48        72         100
# 6                 hilo  19.7297 -155.0900     22.57        88          20
# 7             cherskiy  68.7500  161.3000    -17.16        90         100
# 8        san cristobal   7.7669  -72.2250     20.10        82          82
# 10             sorland  67.6670   12.6934      2.92        70         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      US  1675042085
# 6              0.89      US  1675042020
# 7              2.21      RU  1675042088
# 8              0.88      VE  1675042052
# 10            12.09      NO  1675042089

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                             City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1        san carlos de bariloche -41.1456  -71.3082     21.86        40
# 2                         hobart -42.8794  147.3294     25.03        53
# 3                          vaini -21.2000 -175.2000     29.09        84
# 4                       souillac -20.5167   57.5167     23.21        94
# 5                        rikitea -23.1203 -134.9692     26.15        72
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                20       10.29      AR  1675042086
# 2                40        2.57      AU  1675041994
# 3                40        3.60      TO  1675042000
# 4                20        1.54      MU  1675042055
# 5                 9        3.81      PF  1675041794

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a negative relationship between temperature and latitude")
print("In the northern hemisphere, as the latitude increases the distance from the equator increases")
print("As you move away from the equator, the max temperature decreases.")
# Out:
# The r-value is -0.8357310838672274
# -----------------------------------
# Observations about linear relationship:
# The regression displays a negative relationship between temperature and latitude
# In the northern hemisphere, as the latitude increases the distance from the equator increases
# As you move away from the equator, the max temperature decreases.

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a sligtly positive relationship between temperature and latitude.")
print("In the southern hemisphere, as the latitude increases the distance from the equator decreases")
print("As you move closer to the equator, the max temperature generally increases.")
# Out:
# The r-value is 0.3589596539074365
# -----------------------------------
# Observations about linear relationship:
# The regression displays a sligtly positive relationship between temperature and latitude.
# In the southern hemisphere, as the latitude increases the distance from the equator decreases
# As you move closer to the equator, the max temperature generally increases.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive, though there doesn't appear to be a strong coorelation between humidity and latitude.")
# Out:
# The r-value is 0.3497078016391955
# -----------------------------------
# Observations about linear relationship:
# The relationship is slightly positive, though there doesn't appear to be a strong coorelation between humidity and latitude.

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive.")
print("Humidity increases as cities get closer to the equator.")
# Out:
# The r-value is 0.47857597664841556
# -----------------------------------
# Observations about linear relationship:
# The relationship is slightly positive.
# Humidity increases as cities get closer to the equator.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r-value is 0.23465980789823926
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and cloudiness.

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r-value is 0.17689216994228754
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and cloudiness.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r-value is 0.13716508826927384
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and wind speed.

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r-value is -0.37154782527632135
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and wind speed.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
